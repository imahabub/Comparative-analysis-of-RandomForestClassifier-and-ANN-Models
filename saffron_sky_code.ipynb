# %% [markdown]
# Importing the required python libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as plotx

# %% [markdown]
# Importing the ailine dataset into google colab

# %%
saffron_df= pd.read_csv("/content/UK_NATIONAL_AIRLINES_DATA_CW1 (S) (1).csv", encoding="latin-1")
saffron_df.head(6)
# Out:
#    Ref      id  Gender Satisfied  Age  Age Band   Type of Travel     Class  \
# 0    0   70172    Male         Y   13  Under 18  Personal Travel  Eco Plus
# 1    1    5047    Male         N   25  25 to 34  Business travel  Business
# 2    2  110028  Female         Y   26  25 to 34  Business travel  Business
# 3    3   24026  Female         Y   25  25 to 34  Business travel  Business
# 4    4  119299    Male         Y   61  55 to 64  Business travel  Business
# 5    5  111157  Female         Y   26  25 to 34  Personal Travel       Eco
#
#    Flight Distance          Destination  ... Seat comfort  \
# 0             4760                India  ...            5
# 1              235  Republic of Ireland  ...            1
# 2             4760                India  ...            5
# 3              560               Norway  ...            2
# 4             4760                India  ...            5
# 5             1180                Italy  ...            1
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       5                 4                 3
# 1                       1                 1                 5
# 2                       5                 4                 3
# 3                       2                 2                 5
# 4                       3                 3                 4
# 5                       1                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
# 5                 4                4                 4            1
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
# 5                           0                       0.0
#
# [6 rows x 27 columns]

# %% [markdown]
# Information about the dataset

# %%
saffron_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Ref                                103904 non-null  int64
#  1   id                                 103904 non-null  int64
#  2   Gender                             103904 non-null  object
#  3   Satisfied                          103904 non-null  object
#  4   Age                                103904 non-null  int64
#  5   Age Band                           103904 non-null  object
#  6   Type of Travel                     103904 non-null  object
#  7   Class                              103904 non-null  object
#  8   Flight Distance                    103904 non-null  int64
#  9   Destination                        103904 non-null  object
#  10  Continent                          103904 non-null  object
#  11  Inflight wifi service              103904 non-null  int64
#  12  Departure/Arrival time convenient  103904 non-null  int64
#  13  Ease of Online booking             103904 non-null  int64
#  14  Gate location                      103904 non-null  int64
#  15  Food and drink                     103904 non-null  int64
#  16  Online boarding                    103904 non-null  int64
#  17  Seat comfort                       103904 non-null  int64
#  18  Inflight entertainment             103904 non-null  int64
#  19  On-board service                   103904 non-null  int64
#  20  Leg room service                   103904 non-null  int64
#  21  Baggage handling                   103904 non-null  int64
#  22  Checkin service                    103904 non-null  int64
#  23  Inflight service                   103904 non-null  int64
#  24  Cleanliness                        103904 non-null  int64
#  25  Departure Delay in Minutes         103904 non-null  int64
#  26  Arrival Delay in Minutes           103594 non-null  float64
# dtypes: float64(1), int64(19), object(7)
# memory usage: 21.4+ MB

# %% [markdown]
# Evaluating the null values in the dataset

# %%
saffron_df.isnull().sum()
# Out:
# Ref                                    0
# id                                     0
# Gender                                 0
# Satisfied                              0
# Age                                    0
# Age Band                               0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Destination                            0
# Continent                              0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# dtype: int64

# %% [markdown]
# Determining the duplicate values in the dataset

# %%
saffron_df.duplicated().any()
# Out:
# False

# %% [markdown]
# Removing the null values

# %%
saffron_df.dropna(inplace=True)

# %% [markdown]
# Computing the descriptive statistics

# %%
saffron_df.describe()
# Out:
#                  Ref             id            Age  Flight Distance  \
# count  103594.000000  103594.000000  103594.000000    103594.000000
# mean    51950.102274   64942.428625      39.380466      4164.102361
# std     29997.914016   37460.816597      15.113125      1346.755729
# min         0.000000       1.000000       7.000000       235.000000
# 25%     25960.250000   32562.250000      27.000000      4760.000000
# 50%     51955.500000   64890.000000      40.000000      4760.000000
# 75%     77924.750000   97370.500000      51.000000      4760.000000
# max    103903.000000  129880.000000      85.000000      5940.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count          103594.000000                      103594.000000
# mean                2.522221                           3.060032
# std                 1.447998                           1.525301
# min                 0.000000                           0.000000
# 25%                 1.000000                           2.000000
# 50%                 3.000000                           3.000000
# 75%                 4.000000                           4.000000
# max                 5.000000                           5.000000
#
#        Ease of Online booking  Gate location  Food and drink  Online boarding  \
# count           103594.000000  103594.000000   103594.000000    103594.000000
# mean                 2.756936       2.976968        3.202019         3.250372
# std                  1.398998       1.277805        1.329494         1.349531
# min                  0.000000       0.000000        0.000000         0.000000
# 25%                  2.000000       2.000000        2.000000         2.000000
# 50%                  3.000000       3.000000        3.000000         3.000000
# 75%                  4.000000       4.000000        4.000000         4.000000
# max                  5.000000       5.000000        5.000000         5.000000
#
#         Seat comfort  Inflight entertainment  On-board service  \
# count  103594.000000           103594.000000     103594.000000
# mean        3.399068                3.358254          3.382493
# std         1.365622                1.333144          1.288409
# min         0.000000                0.000000          0.000000
# 25%         2.000000                2.000000          2.000000
# 50%         4.000000                4.000000          4.000000
# 75%         5.000000                4.000000          4.000000
# max         5.000000                5.000000          5.000000
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# count     103594.000000     103594.000000    103594.000000     103594.000000
# mean           3.351275          3.631562         3.304216          3.640665
# std            1.315519          1.181204         1.265502          1.175762
# min            0.000000          0.000000         0.000000          0.000000
# 25%            2.000000          3.000000         3.000000          3.000000
# 50%            4.000000          4.000000         3.000000          4.000000
# 75%            4.000000          5.000000         4.000000          5.000000
# max            5.000000          5.000000         5.000000          5.000000
#
#          Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# count  103594.000000               103594.000000             103594.000000
# mean        3.286291                   14.750719                 15.181275
# std         1.312294                   38.200249                 38.774453
# min         0.000000                    0.000000                  0.000000
# 25%         2.000000                    0.000000                  0.000000
# 50%         3.000000                    0.000000                  0.000000
# 75%         4.000000                   12.000000                 13.000000
# max         5.000000                 1592.000000               1584.000000

# %% [markdown]
# Ploting the relevant variables of the dataset

# %% [markdown]
# Count of Inflight wifi service Ratings based on satisfaction

# %%
plot_inflight=sns.countplot(x ='Inflight wifi service', hue= 'Satisfied',data = saffron_df, palette='Blues')
for label in plot_inflight.containers:
    plot_inflight.bar_label(label)
plt.title('Count of Inflight wifi service Ratings based on satisfaction')
plt.xlabel('Inflight wifi service Rating')
plt.ylabel('Count')
plt.legend(title='Satisfied')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Determining Satisfaction level by Continent

# %%
plot_conti = plotx.histogram(saffron_df, x='Continent', color='Satisfied', barmode='group',
                   title='Determining Satisfaction level by Continent',
                   labels={'Continent level': 'Continent', 'count of passengers': 'Number of Passengers'})
plot_conti.update_layout(xaxis_title='Continent level', yaxis_title='Count of passengers', bargap=0.3)
plot_conti.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d5bdbd3b-7c28-412c-8ae2-2058fa326321" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5bdbd3b-7c28-412c-8ae2-2058fa326321")) {                    Plotly.newPlot(                        "d5bdbd3b-7c28-412c-8ae2-2058fa326321",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Satisfied=Y\u003cbr\u003eContinent=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Y","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Y","offsetgroup":"Y","orientation":"v","showlegend":true,"x":["Asia","Asia","Europe","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Europe","North America","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Europe","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Europe","Asia","Asia","Africa","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Europe","Europe","Asia","Africa","Asia","Asia","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Europe","Asia","Asia","Asia","North America","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Europe","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Europe","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Africa","Asia","North America","Asia","Europe","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Europe","Asia","Europe","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Africa","Europe","Europe","Europe","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","North America","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Europe","Asia","Asia","North America","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Europe","Asia","Asia","Asia","Africa","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Europe","Asia","Asia","Asia","Asia","Asia","Asia","Asia","E ...

# %% [markdown]
# Count of age band based on satisfaction

# %%
plot_age=sns.countplot(x ='Age Band', hue= 'Satisfied',data = saffron_df, palette='husl')
for label in plot_age.containers:
    plot_age.bar_label(label)
plt.title('Count of age band based on satisfaction')
plt.xlabel('Age band')
plt.ylabel('Count')
plt.legend(title='Satisfied')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Count the type of travel based on satisfaction

# %%
plot_type=sns.countplot(x ='Type of Travel', hue= 'Satisfied',data = saffron_df, palette='coolwarm')
for label in plot_type.containers:
    plot_type.bar_label(label)
plt.title('Count of type of travel based on satisfaction')
plt.xlabel('Type of travel')
plt.ylabel('Count')
plt.legend(title='Satisfied')
plt.xticks(rotation=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# Data preprocessing

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
label_encoder_international_dataset = {}
categorical_column_international = ['Gender', 'Satisfied', 'Age Band', 'Type of Travel', 'Class', 'Destination', 'Continent']
for column in categorical_column_international:
    label_encoder_internation= LabelEncoder()
    saffron_df[column] = label_encoder_internation.fit_transform(saffron_df[column])
    label_encoder_international_dataset[column] = label_encoder_internation

# %% [markdown]
# Heatmap generation

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(saffron_df.corr(), annot=True, cmap='Blues')
plt.show()

# %% [markdown]
# Spliting the dataset and fitting the machine learning model

# %%
from sklearn.model_selection import train_test_split

X_international = saffron_df.drop(['Ref', 'id', 'Satisfied', 'Age'], axis=1)
y_international = saffron_df['Satisfied']
X_train, X_test, y_train, y_test = train_test_split(X_international, y_international, test_size=0.3, random_state=42)

# %% [markdown]
# RandomForestClassifier Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, log_loss
from sklearn.model_selection import train_test_split

# %%
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)

# %%
confusion_matrix_rf = confusion_matrix(y_test, y_pred_rf)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
class_report_rf = classification_report(y_test, y_pred_rf)

# %%
plt.figure(figsize=(5, 4))
sns.heatmap(confusion_matrix_rf, annot=True, fmt='g', cmap='inferno')
plt.title('Confusion Matrix of Random Forest model')
plt.xlabel('Predicted values', fontsize=10)
plt.ylabel('Actual values', fontsize=10)
plt.show()

# %%
print(f'Accuracy of Random Forest model: {accuracy_rf:.3f}')
print(class_report_rf)
# Out:
# Accuracy of Random Forest model: 0.989
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97      5675
#            1       0.99      1.00      0.99     25404
#
#     accuracy                           0.99     31079
#    macro avg       0.99      0.98      0.98     31079
# weighted avg       0.99      0.99      0.99     31079

# %%
y_pred_rf_proba = rf_model.predict_proba(X_test)[:, 1]
loss_rf = log_loss(y_test, y_pred_rf_proba)
print(f'Log Loss value for Random Forest: {loss_rf:.3f}')
# Out:
# Log Loss value for Random Forest: 0.057

# %% [markdown]
# ANN Model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
ann_model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
ann_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
ann_model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - accuracy: 0.7157 - loss: 9.2439 - val_accuracy: 0.8250 - val_loss: 0.9601
# Epoch 2/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7654 - loss: 1.6912 - val_accuracy: 0.7926 - val_loss: 0.5831
# Epoch 3/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7974 - loss: 1.6324 - val_accuracy: 0.8248 - val_loss: 3.3053
# Epoch 4/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8077 - loss: 1.3844 - val_accuracy: 0.6004 - val_loss: 1.6040
# Epoch 5/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8193 - loss: 1.0685 - val_accuracy: 0.8679 - val_loss: 0.4674
# Epoch 6/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8296 - loss: 0.9377 - val_accuracy: 0.8318 - val_loss: 0.6089
# Epoch 7/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8354 - loss: 0.8959 - val_accuracy: 0.8289 - val_loss: 1.3570
# Epoch 8/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8380 - loss: 0.7524 - val_accuracy: 0.8414 - val_loss: 0.5500
# Epoch 9/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8374 - loss: 0.7802 - val_accuracy: 0.8813 - val_loss: 0.3895
# Epoch 10/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8276 - loss: 0.8208 - val_accuracy: 0.8789 - val_loss: 0.3816
# Epoch 11/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8381 - loss: 0.7078 - val_accuracy: 0.8945 - val_loss: 0.3191
# Epoch 12/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8433 - loss: 0.5803 - val_accuracy: 0.8453 - val_loss: 0.4639
# Epoch 13/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8392 - loss: 0.5694 - val_accuracy: 0.6903 - val_loss: 0.8813
# Epoch 14/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8547 - loss: 0.4695 - val_accuracy: 0.8696 - val_loss: 0.3366
# Epoch 15/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8486 - loss: 0.4696 - val_accuracy: 0.8782 - val_loss: 0.3327
# Epoch 16/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8601 - loss: 0.3818 - val_accuracy: 0.8944 - val_loss: 0.2770
# Epoch 17/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8586 - loss: 0.3938 - val_accuracy: 0.8398 - val_loss: 0.4020
# Epoch 18/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8661 - loss: 0.3464 - val_accuracy: 0.7620 - val_loss: 0.5462
# Epoch 19/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8579 - loss: 0.3717 - val_accuracy: 0.8835 - val_loss: 0.3051
# Epoch 20/20
# 1813/1813 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8703 - loss: 0.3217 - val_accuracy: 0.8962 - val_loss: 0.2660

# %%
y_pred_ann = ann_model.predict(X_test)
y_pred_ann = (y_pred_ann > 0.5).astype("int32")
# Out:
# 972/972 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix_ann = confusion_matrix(y_test, y_pred_ann)
plt.figure(figsize=(5, 4))
sns.heatmap(confusion_matrix_ann, annot=True, fmt='g', cmap='viridis')
plt.title('Confusion Matrix of ANN model')
plt.xlabel('Predicted values', fontsize=10)
plt.ylabel('Actual values', fontsize=10)
plt.show()

# %%
accuracy_ann = accuracy_score(y_test, y_pred_ann)
print(f'Accuracy of ANN model: {accuracy_ann:.3f}')
# Out:
# Accuracy of ANN model: 0.897

# %%
print(classification_report(y_test, y_pred_ann))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71      5675
#            1       0.94      0.94      0.94     25404
#
#     accuracy                           0.90     31079
#    macro avg       0.83      0.82      0.83     31079
# weighted avg       0.90      0.90      0.90     31079

# %%
loss_ann= log_loss(y_test, y_pred_ann)
print(f'Log Loss value for ANN: {loss_ann:.3f}')
# Out:
# Log Loss value for ANN: 3.730
